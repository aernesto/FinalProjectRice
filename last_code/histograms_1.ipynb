# %%
import numpy as np
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
from mnist_helper_functions import get_inds
import matplotlib.pyplot as plt
# %matplotlib inline
import pickle


mnist0 = input_data.read_data_sets("MNIST_data/", one_hot=False)
N = 110
images       = mnist0.test.images[0:N]
images       = images.reshape((-1, 28, 28))
labels0      = mnist0.test.labels[0:N] #one_hot = False

inds_dict = get_inds(labels0)

pkl_file    = open('pred_labels.pkl', 'rb')
pred_labels = pickle.load(pkl_file)
pkl_file.close()

min_pins_arr = np.load('min_pins_arr.npy')
def draw_occ_images_and_hists(image, pred_labels, inds_dict, min_pins_arr):
    for d in range(10):
        inds         = inds_dict[d]
        print("total number of %d's in test set: "%d)
        print(len(inds))
        occ_image    = images[inds].copy()[0]
        pin          = min_pins_arr[d]
        print("min accuracy patch pins (i,j)-pixel indices on %d's:"%d)
        print(pin)
        #perform occlusion
        occ_image[pin[0,0]: pin[0,1], pin[1,0]: pin[1,1]] = 0
        plt.imshow(occ_image)
        plt.show()
        plt.hist(pred_labels[d], normed=True, bins=10)
        plt.title("Net predicted labels: digit %d occluded at it's min-pin"%d)
        plt.xlabel("label")
        plt.ylabel("Frequency")
        plt.show()
draw_occ_images_and_hists(images, pred_labels, inds_dict, min_pins_arr)

print("done!")
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# total number of 0's in test set:
# 1
# min accuracy patch pins (i,j)-pixel indices on 0's:
# [[0 5]
#  [0 5]]
# total number of 1's in test set:
# 1
# min accuracy patch pins (i,j)-pixel indices on 1's:
# [[ 9 14]
#  [13 18]]
# total number of 2's in test set:
# 1
# min accuracy patch pins (i,j)-pixel indices on 2's:
# [[15 20]
#  [ 8 13]]
# total number of 3's in test set:
# 1
# min accuracy patch pins (i,j)-pixel indices on 3's:
# [[ 7 12]
#  [15 20]]
# total number of 4's in test set:
# 1
# min accuracy patch pins (i,j)-pixel indices on 4's:
# [[11 16]
#  [ 8 13]]
# total number of 5's in test set:
# 1
# min accuracy patch pins (i,j)-pixel indices on 5's:
# [[ 9 14]
#  [ 7 12]]
# total number of 6's in test set:
# 1
# min accuracy patch pins (i,j)-pixel indices on 6's:
# [[14 19]
#  [ 7 12]]
# total number of 7's in test set:
# 1
# min accuracy patch pins (i,j)-pixel indices on 7's:
# [[ 4  9]
#  [ 6 11]]
# total number of 8's in test set:
# 1
# min accuracy patch pins (i,j)-pixel indices on 8's:
# [[ 8 13]
#  [19 24]]
# total number of 9's in test set:
# 1
# min accuracy patch pins (i,j)-pixel indices on 9's:
# [[ 6 11]
#  [12 17]]
# done!
